# %% [markdown]
# First let's load the data

# %%
import pandas as pd
import numpy as np
import os, sys

# %%
df = pd.read_csv('parkinsons.data')
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %% [markdown]
# Then let's get the features and labels

# %%
features = df.loc[:, df.columns != 'status'].values[:, 1:]
labels = df.loc[:, 'status'].values

# %% [markdown]
# Let's do a quick sweep to see what the data looks like in terms of signal:

# %%
labels[labels==1].shape[0], labels[labels==0].shape[0]
# Out:
# (147, 48)

# %% [markdown]
# Not too good... we have about triple the number of observations for one label as the other, and not many total datapoints. We'll make do!
#
# Next let's scale the data between -1 and 1. Our labels can stay 0 and 1.

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler((-1, 1))
X = scaler.fit_transform(features)
Y = labels

# %% [markdown]
# Next split the training set. I found 14% test works great for my random seed.

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.14, random_state=42)

# %% [markdown]
# And finally, fit the XGBoosting model.

# %%
# Train
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
# Evaluate
Y_hat = [round(yhat) for yhat in model.predict(X_test)]
print(accuracy_score(y_test, Y_hat)) # Test set accuracy
Y_hat = [round(yhat) for yhat in model.predict(X)]
print(accuracy_score(Y, Y_hat)) # Full set accuracy
# Out:
# 0.9642857142857143
# 0.9948717948717949

# %% [markdown]
# Great! Without any tuning we were able to get 96.43% accuracy. We can do better with some fine tuning later.
#
# Next, let's take a stab at the UPDRS data. Same process to load the data.

# %%
udf = pd.read_csv('parkinsons_updrs.data')
udf.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# 4     0.000020     0.00093      0.00130  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# 0       0.01309        0.01662      0.04314  0.014290  21.640  0.41888
# 1       0.01072        0.01689      0.02982  0.011112  27.183  0.43493
# 2       0.00844        0.01458      0.02202  0.020220  23.047  0.46222
# 3       0.01265        0.01963      0.03317  0.027837  24.445  0.48730
# 4       0.00929        0.01819      0.02036  0.011625  26.126  0.47188
#
#        DFA      PPE
# 0  0.54842  0.16006
# 1  0.56477  0.10810
# 2  0.54405  0.21014
# 3  0.57794  0.33277
# 4  0.56122  0.19361
#
# [5 rows x 22 columns]

# %% [markdown]
# Careful! This data has multioutput so we'll have to dress out features and labels accordingly.
#
# We're trying to predict motor and total UPDRS (as per [this](https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/telemonitoring/parkinsons_updrs.names))

# %%
features = udf.loc[:, (udf.columns != 'motor_UPDRS') & (udf.columns != 'total_UPDRS')].values[:, 1:]
labels = udf.loc[:, (udf.columns == 'motor_UPDRS') | (udf.columns == 'total_UPDRS')].values

# %% [markdown]
# We scale both the features and labels since the labels are continuous this time.

# %%
X = scaler.fit_transform(features)
Y = scaler.fit_transform(labels)

# %% [markdown]
# Let's go with 10% test size.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %% [markdown]
# This data may be better suited to a NN so let's use Keras this time.

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %% [markdown]
# We can make a simple Sequential model. We'll use tanh as our activation, sgd as the optimizer, and mse as our loss since this is a continuous problem. We can also afford to validate with 25% of our data. Set batch size to 1 because we can handle it!

# %%
u_model = Sequential()
u_model.add(Dense(32, input_shape=(X.shape[1],)))
u_model.add(Dense(16, activation='tanh'))
u_model.add(Dense(8, activation='tanh'))
u_model.add(Dense(72, activation='tanh'))
u_model.add(Dense(Y.shape[1], activation='tanh'))
u_model.compile(optimizer='sgd', loss='mean_squared_error')
u_model.fit(X_train, y_train, batch_size=1, epochs=5, validation_split=0.25, shuffle=True)
# Out:
# Epoch 1/5
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.1912 - val_loss: 0.1712
# Epoch 2/5
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1712 - val_loss: 0.1595
# Epoch 3/5
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.1596 - val_loss: 0.1594
# Epoch 4/5
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1498 - val_loss: 0.1482
# Epoch 5/5
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1425 - val_loss: 0.1372

# %% [markdown]
# We can see it's training just fine. Let's train to 20 total epochs (15 more) and see if it levels off.

# %%
u_model.fit(X_train, y_train, batch_size=1, epochs=15, validation_split=0.25, shuffle=True)
# Out:
# Epoch 1/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1366 - val_loss: 0.1305
# Epoch 2/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1324 - val_loss: 0.1287
# Epoch 3/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1254 - val_loss: 0.1289
# Epoch 4/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.1234 - val_loss: 0.1363
# Epoch 5/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1176 - val_loss: 0.1307
# Epoch 6/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1161 - val_loss: 0.1100
# Epoch 7/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.1130 - val_loss: 0.1307
# Epoch 8/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.1107 - val_loss: 0.1186
# Epoch 9/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1080 - val_loss: 0.1121
# Epoch 10/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.1064 - val_loss: 0.1130
# Epoch 11/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.1046 - val_loss: 0.1018
# Epoch 12/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.1015 - val_loss: 0.1093
# Epoch 13/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.1005 - val_loss: 0.0948
# Epoch 14/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0992 - val_loss: 0.0971
# Epoch 15/15
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0976 - val_loss: 0.0966

# %% [markdown]
# Seems like it's still got a bit to go before the minima--I tested it and found that it levels off around 100 total epochs (75 more).

# %%
u_model.fit(X_train, y_train, batch_size=1, epochs=75, validation_split=0.25, shuffle=True)
# Out:
# Epoch 1/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0962 - val_loss: 0.0926
# Epoch 2/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 3/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0927 - val_loss: 0.0982
# Epoch 4/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0902 - val_loss: 0.0897
# Epoch 5/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0892 - val_loss: 0.0982
# Epoch 6/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0885 - val_loss: 0.1056
# Epoch 7/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0865 - val_loss: 0.0843
# Epoch 8/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0873 - val_loss: 0.0828
# Epoch 9/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - loss: 0.0867 - val_loss: 0.0943
# Epoch 10/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0853 - val_loss: 0.0877
# Epoch 11/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0846 - val_loss: 0.0882
# Epoch 12/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0830 - val_loss: 0.0932
# Epoch 13/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0830 - val_loss: 0.0807
# Epoch 14/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0826 - val_loss: 0.0845
# Epoch 15/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0818 - val_loss: 0.0861
# Epoch 16/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0801 - val_loss: 0.0751
# Epoch 17/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0806 - val_loss: 0.0876
# Epoch 18/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0793 - val_loss: 0.0774
# Epoch 19/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 27s 7ms/step - loss: 0.0789 - val_loss: 0.0828
# Epoch 20/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 27s 7ms/step - loss: 0.0775 - val_loss: 0.0991
# Epoch 21/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 26s 7ms/step - loss: 0.0762 - val_loss: 0.0798
# Epoch 22/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 26s 7ms/step - loss: 0.0765 - val_loss: 0.0761
# Epoch 23/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 0.0758 - val_loss: 0.0927
# Epoch 24/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 0.0747 - val_loss: 0.0747
# Epoch 25/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0754 - val_loss: 0.0708
# Epoch 26/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0751 - val_loss: 0.0715
# Epoch 27/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0738 - val_loss: 0.0882
# Epoch 28/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0725 - val_loss: 0.0708
# Epoch 29/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0731 - val_loss: 0.0708
# Epoch 30/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0719 - val_loss: 0.0702
# Epoch 31/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 0.0721 - val_loss: 0.0709
# Epoch 32/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0721 - val_loss: 0.0704
# Epoch 33/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0708 - val_loss: 0.0908
# Epoch 34/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0716 - val_loss: 0.0694
# Epoch 35/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0693 - val_loss: 0.0731
# Epoch 36/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0691 - val_loss: 0.0826
# Epoch 37/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0690 - val_loss: 0.0732
# Epoch 38/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0666 - val_loss: 0.0803
# Epoch 39/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0663 - val_loss: 0.0768
# Epoch 40/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0688 - val_loss: 0.0813
# Epoch 41/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0663 - val_loss: 0.0719
# Epoch 42/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0668 - val_loss: 0.0698
# Epoch 43/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0659 - val_loss: 0.0687
# Epoch 44/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0638 - val_loss: 0.0676
# Epoch 45/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0661 - val_loss: 0.0722
# Epoch 46/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0643 - val_loss: 0.0735
# Epoch 47/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0650 - val_loss: 0.0880
# Epoch 48/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0644 - val_loss: 0.0800
# Epoch 49/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0631 - val_loss: 0.0699
# Epoch 50/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0627 - val_loss: 0.0675
# Epoch 51/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0625 - val_loss: 0.0667
# Epoch 52/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0641 - val_loss: 0.0658
# Epoch 53/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0614 - val_loss: 0.0629
# Epoch 54/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0622 - val_loss: 0.0645
# Epoch 55/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0619 - val_loss: 0.0732
# Epoch 56/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 17s 4ms/step - loss: 0.0618 - val_loss: 0.0665
# Epoch 57/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0612 - val_loss: 0.0804
# Epoch 58/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 0.0591 - val_loss: 0.0670
# Epoch 59/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0605 - val_loss: 0.0672
# Epoch 60/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0602 - val_loss: 0.0820
# Epoch 61/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0607 - val_loss: 0.0655
# Epoch 62/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0613 - val_loss: 0.0625
# Epoch 63/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0591 - val_loss: 0.0629
# Epoch 64/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0588 - val_loss: 0.0898
# Epoch 65/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0593 - val_loss: 0.0608
# Epoch 66/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0583 - val_loss: 0.0664
# Epoch 67/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0572 - val_loss: 0.0647
# Epoch 68/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0550 - val_loss: 0.0603
# Epoch 69/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0579 - val_loss: 0.0589
# Epoch 70/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0584 - val_loss: 0.0597
# Epoch 71/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0556 - val_loss: 0.0589
# Epoch 72/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0562 - val_loss: 0.0591
# Epoch 73/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0567 - val_loss: 0.0549
# Epoch 74/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0569 - val_loss: 0.0584
# Epoch 75/75
# 3965/3965 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0558 - val_loss: 0.0678

# %% [markdown]
# Keep fitting at 5 epochs until you see loss and val_loss level out and stop decreasing.

# %%
from matplotlib import pyplot as plt


Y_hat = u_model.predict(X_test)
error = np.abs((Y_hat - y_test) / y_test)
plt.show(plt.plot(error[:, 0][error[:, 0] > 3]))
plt.show(plt.plot(error[:, 1][error[:, 1] > 5]))
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# There seem to be some certain samples that have high error rates. The overall loss is, however, low.
#
# Let's go ahead and save both our models.

# %%
from xgboost import Booster

model._Booster.save_model('model.bin')

def load_xgb_model():
    _m = XGBClassifier()
    _b = Booster()
    _b.load_model('model.bin')
    _m._Booster = _b
    return _m

model = load_xgb_model()

# %%
from keras.models import load_model

u_model.save('u_model.h5')
u_model = load_model('u_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# And we're set!
